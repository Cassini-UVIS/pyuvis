# %% [raw]
# ---
# title: "Calibration: Greg method"
# format:
#   html:
#     code-fold: false
# ---

# %% [markdown]
# # Greg's input
# > Tools and tables from Greg about calibration

# %% [markdown]
# > ⚠️ The cells below are marked `#| eval: false` because they require either a user-local calibration table or a live planetarypy PDS index fetch. Run them locally in JupyterLab to inspect outputs.

# %%
from pyuvis import UVISObs, CatalogFilter
from pyuvis.calib.greg import (
    get_star_obs,
    get_spica_obs,
    filter_spica_for_date,
)

# %%
df = get_star_obs()
df.head()

# %%
df[df.duplicated(subset="product_id", keep=False)]

# %%
#| eval: false
uvis = UVISObs("EUV2001_299_20_44")

# %%
#| eval: false
uvis.fuv

# %%
get_star_obs().dtypes

# %%
get_spica_obs().head()

# %%
filter_spica_for_date("1999-01-16").head()

# %%
#| eval: false
cat = CatalogFilter("2002-198")

# %%
#| eval: false
cat.doydate

# %%
#| eval: false
cat.df.START_TIME
